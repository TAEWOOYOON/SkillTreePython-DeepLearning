# %% [markdown]
# <a href="https://colab.research.google.com/github/yebiny/SkillTreePython-DeepLearning/blob/main/01.%EB%94%A5%EB%9F%AC%EB%8B%9Dwith%ED%85%90%EC%84%9C%ED%94%8C%EB%A1%9C%EC%9A%B0-basic/ch01_09_%EC%9D%B4%EB%AF%B8%EC%A7%80%EB%84%B7%EB%AA%A8%EB%8D%B8%EA%B5%AC%ED%98%84_VGG16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ch01.09 이미지넷 모델구현 - VGG16
# ---
#
# * 날짜: 2022-07-11
# * 이름: 고민수
#
# ## 학습내용
#     - VGG 모델 특징에 대해 이해한다.
#     - VGG 모델을 텐서플로우를 이용해 구현한다.

# %% [markdown]
# ## 소개
# ---

# %%
import tensorflow as tf
from tensorflow.keras import models, layers, utils

# %% [markdown]
# ## 구현
# ---

# %%
def VGG_16():
    x = layers.Input(shape=(224,224,3))
    
    y = layers.Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu")(x)
    y = layers.Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu")(y)
    y = layers.MaxPool2D(pool_size=(2,2), strides=(2,2))(y)
    
    y = layers.Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu")(y)
    y = layers.Conv2D(filters=128,kernel_size=(3,3),padding="same", activation="relu")(y)
    y = layers.MaxPool2D(pool_size=(2,2), strides=(2,2))(y)
    
    y = layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu")(y)
    y = layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu")(y)
    y = layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu")(y)
    y = layers.MaxPool2D(pool_size=(2,2), strides=(2,2))(y)

    y = layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(y)
    y = layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(y)
    y = layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(y)
    y = layers.MaxPool2D(pool_size=(2,2), strides=(2,2))(y)
    
    y = layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(y)
    y = layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(y)
    y = layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(y)
    y = layers.MaxPool2D(pool_size=(2,2), strides=(2,2))(y)
    
    y = layers.Flatten()(y)
    y = layers.Dense(units=4096, activation="relu")(y)
    y = layers.Dense(units=4096, activation="relu")(y)
    y = layers.Dense(units=2, activation="softmax")(y)
    
    return models.Model(x,y, name="VGG_16")

# %%
model = VGG_16()
utils.plot_model(model, show_shapes=True)

# %%
model.summary()
# Out:
# Model: "VGG_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_26 (Conv2D)          (None, 224, 224, 64)      1792
#
#  conv2d_27 (Conv2D)          (None, 224, 224, 64)      36928
#
#  max_pooling2d_10 (MaxPoolin  (None, 112, 112, 64)     0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 112, 112, 128)     73856
#
#  conv2d_29 (Conv2D)          (None, 112, 112, 128)     147584
#
#  max_pooling2d_11 (MaxPoolin  (None, 56, 56, 128)      0
#  g2D)
#
#  conv2d_30 (Conv2D)          (None, 56, 56, 256)       295168
#
#  conv2d_31 (Conv2D)          (None, 56, 56, 256)       590080
#
#  conv2d_32 (Conv2D)          (None, 56, 56, 256)       590080
#
#  max_pooling2d_12 (MaxPoolin  (None, 28, 28, 256)      0
#  g2D)
#
#  conv2d_33 (Conv2D)          (None, 28, 28, 512)       1180160
#
# ...
